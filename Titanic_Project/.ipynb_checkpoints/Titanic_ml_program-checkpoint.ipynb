# %% [markdown]
# ##### Titanic project / Linear regresion

# %% [markdown]
# <img src="favicon.jpg" alt="titanic image" />

# %% [markdown]
# ###### Environment initialization

# %%
# %tensorflow_version 2.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

# %% [markdown]
# ###### Dataset loading

# %%
df_train = pd.read_csv('train.csv')
df_eval  = pd.read_csv('eval.csv')

# %% [markdown]
# ###### Data processing

# %%
y_train = df_train.pop('survived')
y_eval  = df_eval.pop('survived')

CATEGORICAL_COLUMN = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck', 'embark_town', 'alone']
NUMERIC_COLUMNS = ['age', 'fare']

feature_columns = []
for feature_name in CATEGORICAL_COLUMN:
    vocabulary = df_train[feature_name].unique()
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))
    
for feature_name in NUMERIC_COLUMNS:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

# %%
feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# ###### convert pandas dataset to tf.data.Dataset Object

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    return input_function

train_input_fn = make_input_fn(df_train, y_train)
eval_input_fn = make_input_fn(df_eval, y_eval, num_epochs=1, shuffle=False)

# %% [markdown]
# ###### creating the model

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
clear_output()

# %% [markdown]
# ###### training the model

# %%
# train
linear_est.train(train_input_fn)
result = linear_est.evaluate(eval_input_fn)

# clear console output
#clear_output()
print('='*115)
print('ACCURACY = {}'.format(result['accuracy']))
print(result)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tm
model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.58047s
# INFO:tensorflow:Finished evaluation at 2022-01-19-14:22:03
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.780303, accuracy_baseline = 0.625, auc = 0.8376798, auc_precision_recall = 0.77774394, average_loss = 0.4728968, global_step = 20000, label/mean = 0.375, loss = 0.45301792, precision = 0.69902915, prediction/mean = 0.41029575, recall = 0.72727275
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: /tmp/tmpd99cmywr/model.ckpt-20000
# ===================================================================================================================
# ACCURACY = 0.7803030014038086
# {'accuracy': 0.780303, 'accuracy_baseline': 0.625, 'auc': 0.8376798, 'auc_precision_recall': 0.77774394, 'average_loss': 0.4728968, 'label/mean': 0.375, 'loss': 0.45301792, 'precision': 0.69902915, 'prediction/mean': 0.41029575, 'recall': 0.72727275, 'global_step': 20000}

# %% [markdown]
# ###### make prediction

# %%
def predict(pos):
    result = list(linear_est.predict(eval_input_fn))
    print('='*70)
    print("prediction survived rate = {} | real survived = {}".format(result[pos]['probabilities'][1], y_eval[pos]))
    print('='*70)

# %%
for i in range(10):
    predict(i)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.0759124830365181 | real survived = 0
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.5562281608581543 | real survived = 0
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.7752008438110352 | real survived = 1
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.6235553622245789 | real survived = 1
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.2428676038980484 | real survived = 1
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.7930129170417786 | real survived = 1
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.3267538547515869 | real survived = 0
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.11772412061691284 | real survived = 0
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.6939097046852112 | real survived = 0
# ======================================================================
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpd99cmywr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ======================================================================
# prediction survived rate = 0.7691898941993713 | real survived = 1
# ======================================================================

# %%
pd.read_csv('eval.csv').head(10)
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0         0    male  35.0                   0      0   8.0500   Third
# 1         0    male  54.0                   0      0  51.8625   First
# 2         1  female  58.0                   0      0  26.5500   First
# 3         1  female  55.0                   0      0  16.0000  Second
# 4         1    male  34.0                   0      0  13.0000  Second
# 5         1  female  15.0                   0      0   8.0292   Third
# 6         0  female   8.0                   3      1  21.0750   Third
# 7         0    male  21.0                   0      0   8.0500   Third
# 8         0  female  18.0                   2      0  18.0000   Third
# 9         1  female  19.0                   0      0   7.8792   Third
#
#       deck  embark_town alone
# 0  unknown  Southampton     y
# 1        E  Southampton     y
# 2        C  Southampton     y
# 3  unknown  Southampton     y
# 4        D  Southampton     y
# 5  unknown   Queenstown     y
# 6  unknown  Southampton     n
# 7  unknown  Southampton     y
# 8  unknown  Southampton     n
# 9  unknown   Queenstown     y
